# %% [markdown]
# <a href="https://colab.research.google.com/github/priyaselva1313-dotcom/PRIYA/blob/main/SPDAY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict={"name":"priya","grade":90,"name":"rose","grade":67,"name":"sherin","grade":89}
print(dict)
# Out:
# {'name': 'sherin', 'grade': 89}

# %%
students = [
    {"name": "priya", "grade": 90},
    {"name": "rose", "grade": 67},
    {"name": "sherin", "grade": 89}
]

avg = sum(student["grade"] for student in students) / len(students)

print("Average Grade:", avg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1509/3916976216.py in <cell line: 0>()
#       1 dict={"name":"priya","grade":90,"name":"rose","grade":67,"name":"sherin","grade":89}
# ----> 2 avg=sum(dict(grade)/len(dict))
#       3 print(avg)
#
# NameError: name 'grade' is not defined

# %%
students = [
    {"name": "priya", "grade": 90},
    {"name": "rose", "grade": 67},
    {"name": "sherin", "grade": 89}
]

avg = sum(student["grade"] for student in students) / len(students)

print("Average Grade:", avg)
# Out:
# Average Grade: 82.0

# %%
students = [
    {"name": "priya", "grade": 90},
    {"name": "rose", "grade": 67},
    {"name": "sherin", "grade": 89}
]
print("highest grade in students")
print ("lowest grade in students")
# Out:
# highest grade in students
# lowest grade in students

# %%
students = [
    {"name": "priya", "grade": 90},
    {"name": "rose", "grade": 67},
    {"name": "sherin", "grade": 89}
]

print("Maximum Grade:", max(student["grade"] for student in students))
print("Minimum Grade:", min(student["grade"] for student in students))
# Out:
# Maximum Grade: 90
# Minimum Grade: 67
